# %%
import pandas as pd

# %%
data = pd.read_csv('..\\0.data\\raw\\train.csv')
print(data.shape)
data.head(5)
# Out:
# (74111, 29)
#          id  log_price property_type        room_type  \
# 0   6901257   5.010635     Apartment  Entire home/apt
# 1   6304928   5.129899     Apartment  Entire home/apt
# 2   7919400   4.976734     Apartment  Entire home/apt
# 3  13418779   6.620073         House  Entire home/apt
# 4   3808709   4.744932     Apartment  Entire home/apt
#
#                                            amenities  accommodates  bathrooms  \
# 0  {"Wireless Internet","Air conditioning",Kitche...             3        1.0
# 1  {"Wireless Internet","Air conditioning",Kitche...             7        1.0
# 2  {TV,"Cable TV","Wireless Internet","Air condit...             5        1.0
# 3  {TV,"Cable TV",Internet,"Wireless Internet",Ki...             4        1.0
# 4  {TV,Internet,"Wireless Internet","Air conditio...             2        1.0
#
#    bed_type cancellation_policy  cleaning_fee  ...    latitude   longitude  \
# 0  Real Bed              strict          True  ...   40.696524  -73.991617
# ...

# %%
print("ColName\t\t" + 'Unique Count\t' + 'Null Count')
for c in data.columns:
    print(c + ' \t\t' + str(data[c].nunique()) + ' \t\t ' + str(data[c].isnull().sum()))
# Out:
# ColName		Unique Count	Null Count
# id 		74111 		 0
# log_price 		767 		 0
# property_type 		35 		 0
# room_type 		3 		 0
# amenities 		67122 		 0
# accommodates 		16 		 0
# bathrooms 		17 		 200
# bed_type 		5 		 0
# cancellation_policy 		5 		 0
# cleaning_fee 		2 		 0
# city 		6 		 0
# description 		73479 		 0
# first_review 		2554 		 15864
# host_has_profile_pic 		2 		 188
# host_identity_verified 		2 		 188
# host_response_rate 		80 		 18299
# host_since 		3087 		 188
# instant_bookable 		2 		 0
# last_review 		1371 		 15827
# latitude 		74111 		 0
# longitude 		74111 		 0
# name 		73359 		 0
# neighbourhood 		619 		 6872
# number_of_reviews 		371 		 0
# review_scores_rating 		54 		 16722
# thumbnail_url 		65883 		 8216
# zipcode 		769 		 966
# bedrooms 		11 		 91
# beds 		18 		 131

# %%
data.describe(include='all')
# Out:
#                   id     log_price property_type        room_type amenities  \
# count   7.411100e+04  74111.000000         74111            74111     74111
# unique           NaN           NaN            35                3     67122
# top              NaN           NaN     Apartment  Entire home/apt        {}
# freq             NaN           NaN         49003            41310       586
# mean    1.126662e+07      4.782069           NaN              NaN       NaN
# std     6.081735e+06      0.717394           NaN              NaN       NaN
# min     3.440000e+02      0.000000           NaN              NaN       NaN
# 25%     6.261964e+06      4.317488           NaN              NaN       NaN
# 50%     1.225415e+07      4.709530           NaN              NaN       NaN
# 75%     1.640226e+07      5.220356           NaN              NaN       NaN
# max     2.123090e+07      7.600402           NaN              NaN       NaN
#
# ...

# %%
print(data['property_type'].unique())
# Out:
# ['Apartment' 'House' 'Condominium' 'Loft' 'Townhouse' 'Hostel'
#  'Guest suite' 'Bed & Breakfast' 'Bungalow' 'Guesthouse' 'Dorm' 'Other'
#  'Camper/RV' 'Villa' 'Boutique hotel' 'Timeshare' 'In-law' 'Boat'
#  'Serviced apartment' 'Castle' 'Cabin' 'Treehouse' 'Tipi' 'Vacation home'
#  'Tent' 'Hut' 'Casa particular' 'Chalet' 'Yurt' 'Earth House'
#  'Parking Space' 'Train' 'Cave' 'Lighthouse' 'Island']

# %%
print(data['room_type'].unique())
# Out:
# ['Entire home/apt' 'Private room' 'Shared room']

# %%
data['bed_type'].unique()
# Out:
# array(['Real Bed', 'Futon', 'Pull-out Sofa', 'Couch', 'Airbed'],
#       dtype=object)

# %%
data['host_has_profile_pic'].unique()
# Out:
# array(['t', nan, 'f'], dtype=object)

# %%
data['city'].unique()
# Out:
# array(['NYC', 'SF', 'DC', 'LA', 'Chicago', 'Boston'], dtype=object)

# %%
data['host_identity_verified'].unique()
# Out:
# array(['t', 'f', nan], dtype=object)

# %%
data.columns

print(data[['number_of_reviews', 'review_scores_rating']].head())
# Out:
#    number_of_reviews  review_scores_rating
# 0                  2                 100.0
# 1                  6                  93.0
# 2                 10                  92.0
# 3                  0                   NaN
# 4                  4                  40.0
