# %% [markdown]
# ### Other SImilar Tools
# ```
# R - ggplot, ggvis
# web visualization toolkits - D3js, HTML5 canvas
# Seaplot, ggplot, HoloViews, Altair and even pandas can be
# used as wrappers around matplot api's.
# ```

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

import numpy as np

# %%
# Setting Styles
plt.style.use('classic')
plt.style.use('seaborn-whitegrid')

# %% [markdown]
# ### Where Matplotlib works
# ```
# in a script
# ipython terminal
# ipython notebook
# ```

# %%
# Display Plots
plt.show()

# %%
# Display in a script
x = np.linspace(0,10,100)
plt.plot(x, np.sin(x))
plt.show()

# %% [markdown]
# #### plt.show() Usage
# One thing to be aware of: the plt.show() command should be used only once per Python session, and is most often seen at the very end of the script. Multiple show() commands can lead to unpredictable backend-dependent behavior, and should mostly be avoided.

# %%
# Display in a Ipython Shell
# %matplotlib

# using plt.show() is not required now
# Out:
# Using matplotlib backend: Qt5Agg

# %% [markdown]
# ### Display in a IPython Notebook
#
# %matplotlib inline - static images in the notebook
# %matplotlib notebook - interactive plots within the notebook

# %%
#Saving figures to file

fig = plt.figure()
plt.plot(x, np.sin(x), '-')
plt.plot(x, np.cos(x), '--')
plt.show()

fig.savefig('trigno_fig.png')

# Useful commands
# 1. fig.canvas.get_supported_filetypes()

# %%
fig.canvas.get_supported_filetypes()
# Out:
# {'ps': 'Postscript',
#  'eps': 'Encapsulated Postscript',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# ### 2 Interfaces
# A confusing feature of Matplotlib is its dual interfaces: a convenient
# MATLAB-style state-based interface, and a more powerful object-oriented interface.

# %%
plt.figure() # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# INFERENCE - 
    # this interface is stateful. keeps track of current
    # fig anf axes. problem - once 2nd panel is created, how to change 
    # first one?

# %%
# (get current figure) and
# (get current axes)
print(plt.gcf())
print(plt.gca())
# Out:
# Figure(432x288)
# AxesSubplot(0.125,0.125;0.775x0.775)

# %% [markdown]
# ### 2 Interfaces(continued) - Object-oriented interface

# %%
# First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
# ### Simple Line Plots

# %%
fig = plt.figure()
ax = plt.axes()

x = np.linspace(0, 10, 1000);
ax.plot(x, np.sin(x))

# %% [markdown]
# the figure (an instance of the class Figure) can be thought of as a single container that contains all the objects representing axes, graphics, text, and labels.
#
# axes (an instance of the class Axes) is what we see above: a bounding
# box with ticks and labels, which will eventually contain the plot elements that make up our visualization.

# %% [markdown]
# ### Adjusting the Plot: Line Colors and Styles

# %%
plt.plot(x, np.sin(x - 0), color='blue') # specify color by name
plt.plot(x, np.sin(x - 1), color='g') # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75') # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44') # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 and 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
# plt.plot(x, x + 4, linestyle='-') # solid
# plt.plot(x, x + 5, linestyle='--') # dashed
# plt.plot(x, x + 6, linestyle='-.') # dashdot
# plt.plot(x, x + 7, linestyle=':'); # dotted

plt.plot(x, x + 0, '-g') # solid green
plt.plot(x, x + 1, '--c') # dashed cyan
plt.plot(x, x + 2, '-.k') # dashdot black
plt.plot(x, x + 3, ':r'); # dotted red

# %% [markdown]
# ### Adjusting the Plot: Axes Limits

# %%
plt.plot(x, np.sin(x))
plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# If for some reason you’d like either axis to be displayed in 
# reverse, you can simply reverse the order of the arguments

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# plt.axis() method allows you to set the x and y limits 
# with a single call, by passing a list that specifies 
# [xmin, xmax, ymin, ymax]

plt.axis([-1, 11, -1.5, 1.5]);
# OR
# plt.axis('tight'); - to automatically tighten the bounds
# plt.axis('equal'); - ensuring an equal aspect ratio so 
#     that on your screen, one unit in x is equal to one unit in y

# %% [markdown]
# ### Labeling Plots

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# ### MatplotLib MATLAB to Object Oriented
# ```
# • plt.xlabel() → ax.set_xlabel()
# • plt.ylabel() → ax.set_ylabel()
# • plt.xlim() → ax.set_xlim()
# • plt.ylim() → ax.set_ylim()
# • plt.title() → ax.set_title()
# ```

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
        xlabel='x', ylabel='sin(x)',
        title='A Simple Plot');

# %% [markdown]
# ### Scatter Plot
# ```
# The primary difference of plt.scatter from plt.plot is that it can be used to create scatter plots where the properties of each individual point (size, face color, edge color, etc.) can be individually controlled or mapped to data.
#
#
# plt.plot can be noticeably more efficient than plt.scatter. The reason is that has the plt.scatter has the capability to render a different size and/or color for each point, so the renderer must do the extra work of constructing each point individually. In plt.plot, on the other hand, the points are always essentially clones of each other
# ```

# %%
rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)
plt.scatter(x, y, c=colors, s=sizes, alpha=0.3, cmap='viridis')
plt.colorbar(); # show color scale

# %% [markdown]
# ### Basic Errorbars

# %%
x = np.linspace(0, 10, 50)
dy = 0.8
y = np.sin(x) + dy * np.random.randn(50)
plt.errorbar(x, y, yerr=dy, fmt='o', color='black',
    ecolor='lightgray', elinewidth=3, capsize=0);

# fmt is a format code to control appearance of lines and points. 
# specify horizontal errorbars (xerr), onesided & other variants

# %% [markdown]
# ### Continuous Errors
# ```
# fill_between function: we pass an x value, then the lower y-bound, then the upper y-bound, and the result is that the area between these regions is filled.
# ```

# %%
from sklearn.gaussian_process import GaussianProcessRegressor

# define the model and draw some data
model = lambda x: x * np.sin(x)
xdata = np.array([1, 3, 5, 6, 8])
ydata = model(xdata)

# Compute the Gaussian process fit
gp = GaussianProcessRegressor()
gp.fit(xdata[:, np.newaxis], ydata)

xfit = np.linspace(0, 10, 1000)
yfit, MSE = gp.predict(xfit[:, np.newaxis], eval_MSE=True)

dyfit = 2 * np.sqrt(MSE) # 2*sigma ~ 95% confidence region

# Visualize the result
plt.plot(xdata, ydata, 'or')
plt.plot(xfit, yfit, '-', color='gray')
plt.fill_between(xfit, yfit - dyfit, yfit + dyfit, 
                color='gray', alpha=0.2)
plt.xlim(0, 10);
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-80-e144c4af8b7d> in <module>
#      11
#      12 xfit = np.linspace(0, 10, 1000)
# ---> 13 yfit, MSE = gp.predict(xfit[:, np.newaxis], eval_MSE=True)
#      14
#      15 dyfit = 2 * np.sqrt(MSE) # 2*sigma ~ 95% confidence region
#
# TypeError: predict() got an unexpected keyword argument 'eval_MSE'

# %% [markdown]
# ### Density and Contour Plots
# #### Visualizing a Three-Dimensional Function

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)

x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)
X, Y = np.meshgrid(x, y)
Z = f(X, Y)

plt.contour(X, Y, Z, 20, cmap='RdGy');

# %%
### Histograms, Binnings, and Density

# %%
data = np.random.randn(1000)
plt.hist(data, bins=30, density=True, alpha=0.5,
    histtype='stepfilled', color='steelblue',
    edgecolor='none');

# %%
x1 = np.random.normal(0, 0.8, 1000)
x2 = np.random.normal(-2, 1, 1000)
x3 = np.random.normal(3, 2, 1000)

kwargs = dict(histtype='stepfilled', alpha=0.3, density=True, bins=40)

plt.hist(x1, **kwargs)
plt.hist(x2, **kwargs)
plt.hist(x3, **kwargs);
